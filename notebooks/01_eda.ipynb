# %% [markdown]
# # EDA – Accounts Receivable

# %%
import pandas as pd
from pathlib import Path
p = Path('../data/raw')
files = list(p.glob('*.xlsx'))
assert files, 'Put the AR .xlsx into data/raw/'
df = pd.read_excel(files[0])
df.head()
